# %%
# Dictionary with the parameters of the files in the ADLS for the Bronze notebook

datasets = [
    {
        "file_name" : "orders"
    },
    {
        "file_name" : "customers"
    },
    {
        "file_name" : "products"
    }
]

# %%
# This command will be used by the Workflow to call the dictionary above

dbutils.jobs.taskValues.set("output_datasets", datasets)
